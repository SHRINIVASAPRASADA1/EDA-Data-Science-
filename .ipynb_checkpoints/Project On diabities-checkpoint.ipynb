# %% [markdown]
# # Library's

# %%
#Numpy for dataprocessing
import numpy as np

#pandas for reading dataset and cleaning dataset 
import pandas as pd

#seaborn for ploting... graph
import seaborn as sbn

#matplotLib for ploting
import matplotlib.pyplot as plt

#os for besic operation ( Not Used if require )
import os

#Skelarn for Model Creation  and Label Encoding 
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier

from sklearn.linear_model import LogisticRegression


#Use train test split to divide dataset into 2 part 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Basic Info about dataset

# %%
#Reading Csv File
dataset = pd.read_csv("diabetes.csv")

# %%
#top 5 row

""" Pregnancies: Number of times pregnant
Glucose: Plasma glucose concentration a 2 hours in an oral glucose tolerance test
BloodPressure: Diastolic blood pressure (mm Hg)
SkinThickness: Triceps skin fold thickness (mm)
Insulin: 2-Hour serum insulin (mu U/ml)
BMI: Body mass index (weight in kg/(height in m)^2)
DiabetesPedigreeFunction: Diabetes pedigree function
Age: Age (years)
Outcome: Class variable (0 or 1) """


dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0    148.0           72.0           35.0      0.0  33.6
# 1          1.0     85.0           66.0           29.0      0.0  26.6
# 2          8.0    183.0           64.0            0.0      0.0  23.3
# 3          1.0     23.0           43.0            NaN      NaN   NaN
# 4          1.0     89.0           66.0           23.0     94.0  28.1
#
#   DiabetesPedigreeFunction   Age  Outcome OutComes
# 0                    0.627  50.0      1.0      yes
# 1                    0.351  31.0      0.0       no
# 2                    0.672  32.0      1.0      yes
# 3                    0.124   NaN      NaN       no
# 4                    0.167  21.0      0.0       no

# %% [markdown]
# # Data Cleaning using Pandas

# %%
#Dataset Information 

"""column labels, column data types, memory usage,
range index, and the number of
cells in each column (non-null values)
"""
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 783 entries, 0 to 782
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               782 non-null    float64
#  1   Glucose                   775 non-null    float64
#  2   BloodPressure             777 non-null    float64
#  3   SkinThickness             773 non-null    float64
#  4   Insulin                   774 non-null    float64
#  5   BMI                       772 non-null    float64
#  6   DiabetesPedigreeFunction  778 non-null    object
#  7   Age                       772 non-null    float64
#  8   Outcome                   780 non-null    float64
#  9   OutComes                  783 non-null    object
# dtypes: float64(8), object(2)
# memory usage: 61.3+ KB

# %%
#Total missing value in each colum
dataset.isna().sum()
# Out:
# Pregnancies                  1
# Glucose                      8
# BloodPressure                6
# SkinThickness               10
# Insulin                      9
# BMI                         11
# DiabetesPedigreeFunction     5
# Age                         11
# Outcome                      3
# OutComes                     0
# dtype: int64

# %%
# Row With Null Value 
missing = dataset.isna().any(axis=1)
dataset[missing]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 3            1.0     23.0           43.0            NaN      NaN   NaN
# 12           2.0     22.0            NaN            1.0      NaN   NaN
# 24           3.0      NaN           76.0           36.0    245.0  31.6
# 26           6.0     92.0           92.0            NaN      0.0  19.9
# 28           9.0    119.0            NaN           35.0      0.0  29.0
# 102         11.0     23.0            NaN            NaN      NaN   NaN
# 228          7.0    119.0            0.0            0.0      0.0  25.2
# 229          1.0      NaN           12.0            NaN      2.0   NaN
# 256          2.0      NaN            NaN           21.0      NaN   NaN
# 275          NaN    179.0           59.0          232.0     22.0  87.0
# 360          1.0      NaN           23.0            NaN      NaN   NaN
# 411          1.0      NaN          132.0            NaN     12.0   NaN
# 486          1.0      NaN          231.0            NaN      NaN   NaN
# 605         23.0     23.0            NaN            NaN      NaN   NaN
# 685         23.0      NaN           23.0            NaN      NaN   NaN
# 779          5.0    121.0           72.0            NaN    112.0  26.2
# 780          2.0      NaN            NaN          213.0      NaN   NaN
#
#     DiabetesPedigreeFunction   Age  Outcome OutComes
# 3                      0.124   NaN      NaN       no
# 12                        22   NaN      1.0      yes
# 24                     0.851  28.0      1.0      yes
# 26                       NaN  28.0      0.0       no
# 28                     0.263  29.0      1.0      yes
# 102                       12   NaN      2.0       no
# 228                      NaN  37.0      0.0       no
# 229                       sd   NaN      NaN       no
# 256                      NaN   NaN      1.0      yes
# 275                      NaN  24.0      3.0       no
# 360                      NaN   NaN      1.0      yes
# 411                       23   NaN     23.0       no
# 486                       23   NaN      1.0      yes
# 605                       12   NaN      NaN       no
# 685                       23   NaN      2.0       no
# 779                    0.245  30.0      0.0       no
# 780                       23   NaN      0.0       no

# %%
#remove Na or null Value 
dataset = dataset.dropna()

# %%
#After Removing  Number of Null Valued Row
missing = dataset.isna().any(axis=1)
dataset[missing]
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome, OutComes]
# Index: []

# %%
#top 6 row in dataset
dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0    148.0           72.0           35.0      0.0  33.6
# 1          1.0     85.0           66.0           29.0      0.0  26.6
# 2          8.0    183.0           64.0            0.0      0.0  23.3
# 4          1.0     89.0           66.0           23.0     94.0  28.1
# 5          0.0    137.0           40.0           35.0    168.0  43.1
#
#   DiabetesPedigreeFunction   Age  Outcome OutComes
# 0                    0.627  50.0      1.0      yes
# 1                    0.351  31.0      0.0       no
# 2                    0.672  32.0      1.0      yes
# 4                    0.167  21.0      0.0       no
# 5                    2.288  33.0      1.0      yes

# %%
#Some Statistical mesurement mean standard div min max 
dataset.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   766.000000  766.000000     766.000000     766.000000  766.000000
# mean      3.835509  120.759791      69.147520      20.569191   79.932115
# std       3.372180   31.920772      19.207036      15.937863  115.320210
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   34.000000
# 75%       6.000000  140.000000      80.000000      32.000000  127.750000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI         Age     Outcome
# count  766.000000  766.000000  766.000000
# mean    31.987598   33.236292    0.347258
# std      7.887950   11.784571    0.476410
# min      0.000000   21.000000    0.000000
# 25%     27.300000   24.000000    0.000000
# 50%     32.000000   29.000000    0.000000
# 75%     36.575000   41.000000    1.000000
# max     67.100000   81.000000    1.000000

# %%
#top 6 Row of dataset 
dataset.head(6)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0    148.0           72.0           35.0      0.0  33.6
# 1          1.0     85.0           66.0           29.0      0.0  26.6
# 2          8.0    183.0           64.0            0.0      0.0  23.3
# 4          1.0     89.0           66.0           23.0     94.0  28.1
# 5          0.0    137.0           40.0           35.0    168.0  43.1
# 6          5.0    116.0           74.0            0.0      0.0  25.6
#
#   DiabetesPedigreeFunction   Age  Outcome OutComes
# 0                    0.627  50.0      1.0      yes
# 1                    0.351  31.0      0.0       no
# 2                    0.672  32.0      1.0      yes
# 4                    0.167  21.0      0.0       no
# 5                    2.288  33.0      1.0      yes
# 6                    0.201  30.0      0.0       no

# %%
#Check Bottom 6 row
dataset.tail(6)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 775          9.0    170.0           74.0           31.0      0.0  44.0
# 776          9.0     89.0           62.0            0.0      0.0  22.5
# 777         10.0    101.0           76.0           48.0    180.0  32.9
# 778          2.0    122.0           70.0           27.0      0.0  36.8
# 781          1.0    126.0           60.0            0.0      0.0  30.1
# 782          1.0     93.0           70.0           31.0      0.0  30.4
#
#     DiabetesPedigreeFunction   Age  Outcome OutComes
# 775                    0.403  43.0      1.0      yes
# 776                    0.142  33.0      0.0       no
# 777                    0.171  63.0      0.0       no
# 778                     0.34  27.0      0.0       no
# 781                    0.349  47.0      1.0      yes
# 782                    0.315  23.0      0.0       no

# %%
#To encode the catogorical to nummeric value Not requied for this dataset becouse OutComes and outcome both are same only we can use outcome 
le = LabelEncoder()
dataset["OutComes"]=le.fit_transform(dataset["OutComes"])

# %% [markdown]
# # Exploratory data analysis

# %%
#check relation between Glucose and age
sbn.lineplot(data=dataset,x="Glucose",y="Age")
# plt.legend()
plt.show()

# %%
#hist plot for all colums in dataset
sbn.histplot(data=dataset)
plt.show()

# %%
#graphical representation of the distribution of a dataset
sbn.heatmap(dataset.corr())
plt.show()
# Out:
# /tmp/ipykernel_15150/1882981518.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sbn.heatmap(dataset.corr())

# %%
#check frequency distribution of dataset colums
dataset.hist(figsize=(40,40))
plt.show()

# %%
#check relation between Pregnancies and Insulin
sbn.lineplot(data=dataset,x="Pregnancies",y="Insulin")
# plt.legend()
plt.show()

# %%
#check relation between DiabetesPedigreeFunction and Age
sbn.lineplot(data=dataset,x="DiabetesPedigreeFunction",y="Age")
# plt.legend()
plt.show()

# %%
def diagnostic_plots(df, variable,target):
    # The function takes a dataframe (df) and
    # the variable of interest as arguments.

    # Define figure size.
    plt.figure(figsize=(20, 7))

    # histogram
    plt.subplot(1, 4, 1)
    sbn.histplot(df[variable], kde = True,color='r')
    plt.title('Histogram')


    # scatterplot
    plt.subplot(1, 4, 2)
    plt.scatter(df[variable],df[target],color = 'g')
    plt.title('Scatterplot')
    
    
    # boxplot
    try:
        plt.subplot(1, 4, 3)
        sbn.boxplot(y=df[variable],color = 'b')
        plt.title('Boxplot')
    except Exception as ex:
        print(ex)
    
    # barplot
    plt.subplot(1, 4, 4)
    sbn.barplot(x = target, y = variable, data = df)   
    plt.title('Barplot')
    
    
    plt.show()
    
for item in dataset:
    diagnostic_plots(dataset,item,'Outcome')
# Out:
# Vertical orientation requires numeric `y` variable.

# %% [markdown]
# #  Extract the Label and Features

# %%
#get the output variable and convert that to Int32
label = dataset['Outcome'].astype("int32")

# %%
#Drop the OutComes 
dataset= dataset.drop("OutComes",axis=1)

# %%
#Select all colum as features except Outcome in order to predict outcome
features = dataset.drop("Outcome",axis=1)

# %%
#top 4 row of features
features.head(4)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0    148.0           72.0           35.0      0.0  33.6
# 1          1.0     85.0           66.0           29.0      0.0  26.6
# 2          8.0    183.0           64.0            0.0      0.0  23.3
# 4          1.0     89.0           66.0           23.0     94.0  28.1
#
#   DiabetesPedigreeFunction   Age
# 0                    0.627  50.0
# 1                    0.351  31.0
# 2                    0.672  32.0
# 4                    0.167  21.0

# %%
#to 4 row of label
label.head(4)
# Out:
# 0    1
# 1    0
# 2    1
# 4    0
# Name: Outcome, dtype: int32

# %% [markdown]
# # split the data into training and testing

# %%
#split the dataset into train set and test set
#xtrain = train features
#ytrain = outcome value of xtrain

#xtest = testing features
#ytest = test features outcome values 

# the ratio is 80% = trainset   20% = testset
xtrain,xtest,ytrain,ytest = train_test_split(features,label)

# %% [markdown]
# # DecisionTreeClassifier

# %%
#since it is a classification problem we are using DecesionTreeClassifre Or LogisticRegression
model = DecisionTreeClassifier()

#fit the data into model 
model.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
#We are getting 70% accuracy in this dataset
model.score(xtest,ytest)
# Out:
# 0.7604166666666666

# %%
pred = model.predict(xtest)
print(f"total % of accuracy we got {accuracy_score(ytest,pred)*100} %")
# Out:
# total % of accuracy we got 76.04166666666666 %

# %%
#mean of pred and ytest (  actually mean is not good for this )
print(f"the mean of predicted is {pred.mean()}  and mean of original is {ytest.mean()}")
# Out:
# the mean of predicted is 0.328125  and mean of original is 0.296875

# %% [markdown]
# # Logistic Regression Model

# %%
#try with Logistic regression
model = LogisticRegression()
model.fit(xtrain,ytrain)
# Out:
# /home/prasada/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
#accuracy score
model.score(xtest,ytest)
# Out:
# 0.765625

# %%
#accuracy score using metrix
pred = model.predict(xtest)
accuracy_score(ytest,pred)
# Out:
# 0.765625

# %%
#mena value of predicted
pred.mean()
# Out:
# 0.19791666666666666

# %%
#mean value of actual
ytest.mean()
# Out:
# 0.296875
